# %% [markdown]
# <a href="https://colab.research.google.com/github/buthaina279/P4DS/blob/main/vegetables_and_toys_models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
MODELS = [
    { #1 VT/V
     'DOMAIN': {1,2,3},
     'V'     : {1,2},
     'T'     : {3},
     'B'     : {(2,1),(3,1)} 
    },
    { #2 T/V/V
     'DOMAIN': {1,2,3},
     'V'     : {1,2},
     'T'     : {3},
     'B'     : {(3,2),(2,1)} 
    },   
    { #3 T/VTV/V
     'DOMAIN': {1,2,3,4,5},
     'V'     : {1,2,3},
     'T'     : {4,5},
     'B'     : {(5,2), (2,1),(4,1),(3,1) } 
    },   
    { #4 TV/V/V
     'DOMAIN': {1,2,3,4},
     'V'     : {1,2,3},
     'T'     : {4},
     'B'     : {(4,2), (3,2),(2,1) } 
    },   
    { #5 T/VV/V
     'DOMAIN': {1,2,3,4},
     'V'     : {1,2,3},
     'T'     : {4},
     'B'     : {(4,2), (2,1),(3,1) } 
    },   
    { #6 TV/VT/V
     'DOMAIN': {1,2,3,4,5},
     'V'     : {1,2,3},
     'T'     : {4,5},
     'B'     : {(5,2), (3,4),(2,1),(4,1) } 
    }, 
    { #7 T/VT/V
     'DOMAIN': {1,2,3,4},
     'V'     : {1,2},
     'T'     : {3,4},
     'B'     : {(4,2), (2,1),(3,1)} 
    }, 
    { #8 TT/VV/V
     'DOMAIN': {1,2,3,4,5},
     'V'     : {1,2,3},
     'T'     : {4,5},
     'B'     : {(4,2), (5,3),(2,1),(3,1) } 
    }, 
    { #9 VV/T/V
     'DOMAIN': {1,2,3,4},
     'V'     : {1,2,3},
     'T'     : {4},
     'B'     : {(2,4), (3,4),(4,1) } 
    }, 
    { #10 VTV/V
     'DOMAIN': {1,2,3,4},
     'V'     : {1,2,3},
     'T'     : {4},
     'B'     : {(2,1), (4,1),(3,1) } 
    }, 
    { #11 VT/VT/V
     'DOMAIN': {1,2,3,4,5},
     'V'     : {1,2,3},
     'T'     : {4,5},
     'B'     : {(3,2),(5,2), (2,1),(4,1) } 
    }, 
    { #12 V/TV/V
     'DOMAIN': {1,2,3,4},
     'V'     : {1,2,3},
     'T'     : {4},
     'B'     : {(3,2), (4,1),(2,1) } 
    }, 
    { #13 V/T/V
     'DOMAIN': {1,2,3},
     'V'     : {1,2},
     'T'     : {3},
     'B'     : {(2,3), (3,1) } 
    }, 
    { #14 TT/TVV/V
     'DOMAIN': {1,2,3,4,5,6},
     'V'     : {1,2,3},
     'T'     : {4,5,6},
     'B'     : {(5,2), (6,3),(4,1),(2,1),(3,1) } 
    }, 
    { #15 V/TV/V
     'DOMAIN': {1,2,3,4},
     'V'     : {1,2,3},
     'T'     : {4},
     'B'     : {(3,4), (4,1),(2,1) } 
    }

    ## Maybe add more??
]
